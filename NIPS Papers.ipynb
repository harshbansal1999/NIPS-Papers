# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing modules
papers=pd.read_csv('papers.csv')

# %%
papers.head()
# Out:
#      id  year                                              title event_type  \
# 0     1  1987  Self-Organization of Associative Database and ...        NaN
# 1    10  1987  A Mean Field Theory of Layer IV of Visual Cort...        NaN
# 2   100  1988  Storing Covariance by the Associative Long-Ter...        NaN
# 3  1000  1994  Bayesian Query Construction for Neural Network...        NaN
# 4  1001  1994  Neural Network Ensembles, Cross Validation, an...        NaN
#
#                                             pdf_name          abstract  \
# 0  1-self-organization-of-associative-database-an...  Abstract Missing
# 1  10-a-mean-field-theory-of-layer-iv-of-visual-c...  Abstract Missing
# 2  100-storing-covariance-by-the-associative-long...  Abstract Missing
# 3  1000-bayesian-query-construction-for-neural-ne...  Abstract Missing
# 4  1001-neural-network-ensembles-cross-validation...  Abstract Missing
#
#                                           paper_text
# 0  767\n\nSELF-ORGANIZATION OF ASSOCIATIVE DATABA...
# 1  683\n\nA MEAN FIELD THEORY OF LAYER IV OF VISU...
# 2  394\n\nSTORING COVARIANCE BY THE ASSOCIATIVE\n...
# 3  Bayesian Query Construction for Neural\nNetwor...
# 4  Neural Network Ensembles, Cross\nValidation, a...

# %%
papers.drop(["id",'pdf_name',"event_type"],axis=1,inplace=True)

# %%
group=papers.groupby("year")
#papers=pd.DataFrame(papers)

# %%
group.head()
# Out:
#       year                                              title  \
# 0     1987  Self-Organization of Associative Database and ...
# 1     1987  A Mean Field Theory of Layer IV of Visual Cort...
# 2     1988  Storing Covariance by the Associative Long-Ter...
# 3     1994  Bayesian Query Construction for Neural Network...
# 4     1994  Neural Network Ensembles, Cross Validation, an...
# 5     1994  Using a neural net to instantiate a deformable...
# 6     1994           Plasticity-Mediated Competitive Learning
# 7     1994  ICEG Morphology Classification using an Analog...
# 13    1988  Training Multilayer Perceptrons with the Exten...
# 24    1988  An Application of the Principle of Maximum Inf...
# 26    1995       The Gamma MLP for Speech Phoneme Recognition
# 27    1995  A Multiscale Attentional Framework for Relaxat...
# 28    1995  Correlated Neuronal Response: Time Scales and ...
# 29    1995                     Onset-based Sound Segmentation
# 30    1995  A model of transparent motion and non-transpar...
# 35    1988  An Adaptive Network That Learns Sequences of T...
# 46    1988        Digital Realisation of Self-Organising Maps
# 111   1987  Microelectronic Implementations of Connectioni...
# 193   1996    Statistical Mechanics of the Mixture of Experts
# 194   1996  Microscopic Equations in Rough Energy Landscap...
# 195   1996  An Architectural Mechanism for Direction-tuned...
# 196   1996  Maximum Likelihood Blind Source Separation: A ...
# 198   1996  Representing Face Images for Emotion Classific...
# 219   1987  Using Neural Networks to Improve Cochlear Impl...
# 328   1987   Temporal Patterns of Activity in Neural Networks
# 363   1997  Recovering Perspective Pose with a Dual Step E...
# 364   1997      Mapping a Manifold of Perceptual Observations
# 365   1997  The Efficiency and the Robustness of Natural G...
# 366   1997                  Features as Sufficient Statistics
# 367   1997  Training Methods for Adaptive Boosting of Neur...
# ...    ...                                                ...
# 4663  2014               Top Rank Optimization in Linear Time
# 4664  2014       SerialRank: Spectral Ranking using Seriation
# 4665  2014          Magnitude-sensitive preference formation`
# 4666  2014  Learning Mixed Multinomial Logit Model from Or...
# 4667  2014  Near-Optimal Density Estimation in Near-Linear...
# 5118  2015  Texture Synthesis Using Convolutional Neural N...
# 5119  2015  Convolutional Neural Networks with Intra-Layer...
# 5120  2015                      Grammar as a Foreign Language
# 5121  2015  Recursive Training of 2D-3D Convolutional Netw...
# 5122  2015      Generative Image Modeling Using Spatial LSTMs
# 5379  1992  Using Prior Knowledge in a NNPDA to Learn Cont...
# 5390  1992     An Analog VLSI Chip for Radial Basis Functions
# 5401  1992  Automatic Learning Rate Maximization by On-Lin...
# 5413  1992  Computing with Almost Optimal Size Neural Netw...
# 5424  1992  Silicon Auditory Processors as Computer Periph...
# 5565  2016                         Optimistic Gittins Indices
# 5566  2016  Sub-sampled Newton Methods with Non-uniform Sa...
# 5567  2016  Budgeted stream-based active learning via adap...
# 5568  2016    Sequential Neural Models with Stochastic Layers
# 5570  2016  Stochastic Gradient Methods for Distributional...
# 6197  2017  Wider and Deeper, Cheaper and Faster: Tensoriz...
# 6198  2017  Concentration of Multilinear Functions of the ...
# 6199  2017                  Deep Subspace Clustering Networks
# 6200  2017         Attentional Pooling for Action Recognition
# 6202  2017                  On the Consistency of Quick Shift
# 6820  1993  Amplifying and Linearizing Apical Synaptic Inp...
# 6831  1993  A Massively-Parallel SIMD Processor for Neural...
# 6842  1993  Central and Pairwise Data Clustering by Compet...
# 6854  1993  Bayesian Backprop in Action: Pruning, Committe...
# 6865  1993  Unsupervised Parallel Feature Extraction from ...
#
#                                                abstract  \
# 0                                      Abstract Missing
# 1                                      Abstract Missing
# 2                                      Abstract Missing
# 3                                      Abstract Missing
# 4                                      Abstract Missing
# 5                                      Abstract Missing
# 6                                      Abstract Missing
# 7                                      Abstract Missing
# 13                                     Abstract Missing
# 24                                     Abstract Missing
# 26                                     Abstract Missing
# 27                                     Abstract Missing
# 28                                     Abstract Missing
# 29                                     Abstract Missing
# 30                                     Abstract Missing
# 35                                     Abstract Missing
# 46                                     Abstract Missing
# 111                                    Abstract Missing
# 193                                    Abstract Missing
# 194                                    Abstract Missing
# 195                                    Abstract Missing
# 196                                    Abstract Missing
# 198                                    Abstract Missing
# 219                                    Abstract Missing
# 328                                    Abstract Missing
# 363                                    Abstract Missing
# 364                                    Abstract Missing
# 365                                    Abstract Missing
# 366                                    Abstract Missing
# 367                                    Abstract Missing
# ...                                                 ...
# 4663  Bipartite ranking aims to learn a real-valued ...
# 4664  We describe a seriation algorithm for ranking ...
# 4665  Our understanding of the neural computations t...
# 4666  Motivated by generating personalized recommend...
# 4667  Let $p$ be an unknown and arbitrary probabilit...
# 5118  Here we introduce a new model of natural textu...
# 5119  Scene labeling is a challenging computer visio...
# 5120  Syntactic constituency parsing is a fundamenta...
# 5121  Efforts to automate the reconstruction of neur...
# 5122  Modeling the distribution of natural images is...
# 5379                                   Abstract Missing
# 5390                                   Abstract Missing
# 5401                                   Abstract Missing
# 5413                                   Abstract Missing
# 5424                                   Abstract Missing
# 5565  Starting with the Thomspon sampling algorithm,...
# 5566  We consider the problem of finding the minimiz...
# 5567  Active learning enables us to reduce the annot...
# 5568  How can we efficiently propagate uncertainty i...
# 5570  We develop efficient solution methods for a ro...
# 6197  Long Short-Term Memory (LSTM) is a popular app...
# 6198  We prove near-tight concentration of measure f...
# 6199  We present a novel deep neural network archite...
# 6200  We introduce a simple yet surprisingly powerfu...
# 6202  Quick Shift is a popular mode-seeking and clus...
# 6820                                   Abstract Missing
# 6831                                   Abstract Missing
# 6842                                   Abstract Missing
# 6854                                   Abstract Missing
# 6865                                   Abstract Missing
#
#                                              paper_text
# 0     767\n\nSELF-ORGANIZATION OF ASSOCIATIVE DATABA...
# 1     683\n\nA MEAN FIELD THEORY OF LAYER IV OF VISU...
# 2     394\n\nSTORING COVARIANCE BY THE ASSOCIATIVE\n...
# 3     Bayesian Query Construction for Neural\nNetwor...
# 4     Neural Network Ensembles, Cross\nValidation, a...
# 5     U sing a neural net to instantiate a\ndeformab...
# 6     Plasticity-Mediated Competitive Learning\n\nTe...
# 7     ICEG Morphology Classification using an\nAnalo...
# 13    133\n\nTRAINING MULTILAYER PERCEPTRONS WITH TH...
# 24    186\n\nAN APPLICATION OF THE PRINCIPLE OF\nMAX...
# 26    The Gamma MLP for Speech Phoneme\nRecognition\...
# 27    A Multiscale Attentional Framework for\nRelaxa...
# 28    Correlated Neuronal Response:\nTime Scales and...
# 29    Onset-based Sound Segmentation\n\nLeslie S. Sm...
# 30    A model of transparent motion and\nnon-transpa...
# 35    653\n\nAN ADAPTIVE NETWORK THAT LEARNS\nSEQUEN...
# 46    728\n\nDIGITAL REALISATION OF SELF-ORGANISING ...
# 111   515\n\nMICROELECTRONIC IMPLEMENTATIONS OF CONN...
# 193   Statistical Mechanics of the Mixture of\nExper...
# 194   Microscopic Equations in Rough Energy\nLandsca...
# 195   An Architectural Mechanism for\nDirection-tune...
# 196   Maximum Likelihood Blind Source\nSeparation: A...
# 198   Representing Face Images for Emotion\nClassifi...
# 219   783\n\nUSING NEURAL NETWORKS TO IMPROVE\nCOCHL...
# 328   297\n\nTEMPORAL PATTERNS OF ACTIVITY IN\nNEURA...
# 363   Recovering Perspective Pose with a Dual\nStep ...
# 364   Mapping a manifold of perceptual observations\...
# 365   The Efficiency and The Robustness of\nNatural ...
# 366   Features as Sufficient Statistics\nD. Geiger ?...
# 367   Training Methods for Adaptive Boosting\nof Neu...
# ...                                                 ...
# 4663  Top Rank Optimization in Linear Time\n\nNan Li...
# 4664  SerialRank: Spectral Ranking using Seriation\n...
# 4665  Magnitude-sensitive preference formation\n\nNi...
# 4666  Learning Mixed Multinomial Logit Model from\nO...
# 4667  Near?Optimal Density Estimation in Near?Linear...
# 5118  Texture Synthesis Using Convolutional Neural\n...
# 5119  Convolutional Neural Networks with Intra-layer...
# 5120  Grammar as a Foreign Language\n\nOriol Vinyals...
# 5121  Recursive Training of 2D-3D Convolutional Netw...
# 5122  Generative Image Modeling Using Spatial LSTMs\...
# 5379  Using Prior Knowledge in a NNPDA to Learn\nCon...
# 5390  An Analog VLSI Chip for Radial Basis Functions...
# 5401  Automatic Learning Rate Maximization\nby On-Li...
# 5413  Computing with Almost Optimal Size Neural\nNet...
# 5424  Silicon Auditory Processors\nas\nComputer Peri...
# 5565  Optimistic Gittins Indices\nEli Gutin\nOperati...
# 5566  Sub-sampled Newton Methods\nwith Non-uniform S...
# 5567  Budgeted stream-based active learning\nvia ada...
# 5568  Sequential Neural Models with Stochastic Layer...
# 5570  Stochastic Gradient Methods for Distributional...
# 6197  Wider and Deeper, Cheaper and Faster:\nTensori...
# 6198  Concentration of Multilinear Functions of the ...
# 6199  Deep Subspace Clustering Networks\n\nPan Ji?\n...
# 6200  Attentional Pooling for Action Recognition\n\n...
# 6202  On the Consistency of Quick Shift\n\nHeinrich ...
# 6820  Amplifying and Linearizing Apical\nSynaptic In...
# 6831  A Massively-Parallel SIMD Processor for\nNeura...
# 6842  Central and Pairwise Data Clustering by\nCompe...
# 6854  Bayesian Backprop in Action:\nPruning, Committ...
# 6865  Unsupervised Parallel Feature Extraction\nfrom...
#
# [155 rows x 4 columns]

# %%
count=group.size()

# %%
count.plot(kind='bar')

# %%
import re

# %%
papers['title_processed'] = papers['title'].map(lambda x: re.sub('[,\.!?]', '', x))

# %%
papers['title_processed'] =papers['title_processed'].str.lower()

# %%
papers.head()
# Out:
#    year                                              title          abstract  \
# 0  1987  Self-Organization of Associative Database and ...  Abstract Missing
# 1  1987  A Mean Field Theory of Layer IV of Visual Cort...  Abstract Missing
# 2  1988  Storing Covariance by the Associative Long-Ter...  Abstract Missing
# 3  1994  Bayesian Query Construction for Neural Network...  Abstract Missing
# 4  1994  Neural Network Ensembles, Cross Validation, an...  Abstract Missing
#
#                                           paper_text  \
# 0  767\n\nSELF-ORGANIZATION OF ASSOCIATIVE DATABA...
# 1  683\n\nA MEAN FIELD THEORY OF LAYER IV OF VISU...
# 2  394\n\nSTORING COVARIANCE BY THE ASSOCIATIVE\n...
# 3  Bayesian Query Construction for Neural\nNetwor...
# 4  Neural Network Ensembles, Cross\nValidation, a...
#
#                                      title_processed
# 0  self-organization of associative database and ...
# 1  a mean field theory of layer iv of visual cort...
# 2  storing covariance by the associative long-ter...
# 3  bayesian query construction for neural network...
# 4  neural network ensembles cross validation and ...

# %%
from wordcloud import WordCloud

# %%
longstring="".join(papers["title_processed"])

# %%
wc=WordCloud()

# %%
wc.generate(longstring)
wc.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0xBC91CB3F98>

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
def plot_10_most_common_words(count_data, count_vectorizer):
    import matplotlib.pyplot as plt
    words = count_vectorizer.get_feature_names()
    total_counts = np.zeros(len(words))
    for t in count_data:
        total_counts+=t.toarray()[0]
    
    count_dict = (zip(words, total_counts))
    count_dict = sorted(count_dict, key=lambda x:x[1], reverse=True)[0:10]
    words = [w[0] for w in count_dict]
    counts = [w[1] for w in count_dict]
    x_pos = np.arange(len(words)) 

    plt.bar(x_pos, counts,align='center')
    plt.xticks(x_pos, words, rotation=90) 
    plt.xlabel('words')
    plt.ylabel('counts')
    plt.title('10 most common words')
    plt.show()

# %%
vectorizer=CountVectorizer(stop_words='english')

# %%
x=vectorizer.fit_transform(longstring)

# %%
plot_10_most_common_words(x,vectorizer)

# %%
import warnings
warnings.simplefilter("ignore", DeprecationWarning)

# %%
from sklearn.decomposition import LatentDirichletAllocation as LDA

# %%
def print_topics(model, count_vectorizer, n_top_words):
    words = count_vectorizer.get_feature_names()
    for topic_idx, topic in enumerate(model.components_):
        print("\nTopic #%d:" % topic_idx)
        print(" ".join([words[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))

# %%
number_topics = 10
number_words = 40

# %%
lda = LDA(n_components=number_topics)
lda.fit(x)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.7,
#                           learning_method='batch', learning_offset=10.0,
#                           max_doc_update_iter=100, max_iter=10,
#                           mean_change_tol=0.001, n_components=10, n_jobs=None,
#                           perp_tol=0.1, random_state=None,
#                           topic_word_prior=None, total_samples=1000000.0,
#                           verbose=0)

# %%
print("Topics found via LDA:")
print_topics(lda,vectorizer,number_words)
# Out:
# Topics found via LDA:
#
# Topic #0:
# zype hintidentification histogramcausal hips hippocampusbayesian hintstemporal hintsonline hintsasymptotics hinder histogramsfactoring hillclimbing hill highway higgs hierarchiesvariable hierarchiessupport histograms histogramsinferring hierarchiesrao hmmssparse holonscell holographic holland holdout hmmstable hmmsspike hmmsgp histogramslearning hmmsa hmmbiasing hjb hitterslarge history histologically hierarchiesscale hierarchieslearning homeostasis healthcare hedgea hedge
#
# Topic #1:
# zype hintidentification histogramcausal hips hippocampusbayesian hintstemporal hintsonline hintsasymptotics hinder histogramsfactoring hillclimbing hill highway higgs hierarchiesvariable hierarchiessupport histograms histogramsinferring hierarchiesrao hmmssparse holonscell holographic holland holdout hmmstable hmmsspike hmmsgp histogramslearning hmmsa hmmbiasing hjb hitterslarge history histologically hierarchiesscale hierarchieslearning homeostasis healthcare hedgea hedge
#
# Topic #2:
# learning neural using model based networks models network bayesian gaussian inference time multi sparse linear stochastic analysis visual kernel deep data markov optimization image reinforcement estimation non information feature large optimal gradient process classification algorithms algorithm clustering approach recurrent random
#
# Topic #3:
# zype hintidentification histogramcausal hips hippocampusbayesian hintstemporal hintsonline hintsasymptotics hinder histogramsfactoring hillclimbing hill highway higgs hierarchiesvariable hierarchiessupport histograms histogramsinferring hierarchiesrao hmmssparse holonscell holographic holland holdout hmmstable hmmsspike hmmsgp histogramslearning hmmsa hmmbiasing hjb hitterslarge history histologically hierarchiesscale hierarchieslearning homeostasis healthcare hedgea hedge
#
# Topic #4:
# zype hintidentification histogramcausal hips hippocampusbayesian hintstemporal hintsonline hintsasymptotics hinder histogramsfactoring hillclimbing hill highway higgs hierarchiesvariable hierarchiessupport histograms histogramsinferring hierarchiesrao hmmssparse holonscell holographic holland holdout hmmstable hmmsspike hmmsgp histogramslearning hmmsa hmmbiasing hjb hitterslarge history histologically hierarchiesscale hierarchieslearning homeostasis healthcare hedgea hedge
#
# Topic #5:
# zype hintidentification histogramcausal hips hippocampusbayesian hintstemporal hintsonline hintsasymptotics hinder histogramsfactoring hillclimbing hill highway higgs hierarchiesvariable hierarchiessupport histograms histogramsinferring hierarchiesrao hmmssparse holonscell holographic holland holdout hmmstable hmmsspike hmmsgp histogramslearning hmmsa hmmbiasing hjb hitterslarge history histologically hierarchiesscale hierarchieslearning homeostasis healthcare hedgea hedge
#
# Topic #6:
# zype hintidentification histogramcausal hips hippocampusbayesian hintstemporal hintsonline hintsasymptotics hinder histogramsfactoring hillclimbing hill highway higgs hierarchiesvariable hierarchiessupport histograms histogramsinferring hierarchiesrao hmmssparse holonscell holographic holland holdout hmmstable hmmsspike hmmsgp histogramslearning hmmsa hmmbiasing hjb hitterslarge history histologically hierarchiesscale hierarchieslearning homeostasis healthcare hedgea hedge
#
# Topic #7:
# zype hintidentification histogramcausal hips hippocampusbayesian hintstemporal hintsonline hintsasymptotics hinder histogramsfactoring hillclimbing hill highway higgs hierarchiesvariable hierarchiessupport histograms histogramsinferring hierarchiesrao hmmssparse holonscell holographic holland holdout hmmstable hmmsspike hmmsgp histogramslearning hmmsa hmmbiasing hjb hitterslarge history histologically hierarchiesscale hierarchieslearning homeostasis healthcare hedgea hedge
#
# Topic #8:
# zype hintidentification histogramcausal hips hippocampusbayesian hintstemporal hintsonline hintsasymptotics hinder histogramsfactoring hillclimbing hill highway higgs hierarchiesvariable hierarchiessupport histograms histogramsinferring hierarchiesrao hmmssparse holonscell holographic holland holdout hmmstable hmmsspike hmmsgp histogramslearning hmmsa hmmbiasing hjb hitterslarge history histologically hierarchiesscale hierarchieslearning homeostasis healthcare hedgea hedge
#
# Topic #9:
# zype hintidentification histogramcausal hips hippocampusbayesian hintstemporal hintsonline hintsasymptotics hinder histogramsfactoring hillclimbing hill highway higgs hierarchiesvariable hierarchiessupport histograms histogramsinferring hierarchiesrao hmmssparse holonscell holographic holland holdout hmmstable hmmsspike hmmsgp histogramslearning hmmsa hmmbiasing hjb hitterslarge history histologically hierarchiesscale hierarchieslearning homeostasis healthcare hedgea hedge
